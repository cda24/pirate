# %% [markdown]
# ### Demonstration of Regions

# %% [markdown]
# Walk through of key features in the Region library and ROI classes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
colors = list(mcolors.TABLEAU_COLORS)
# %matplotlib inline
plt.rcParams['figure.dpi'] = 120

# %%
from pirate.region import ROI

# %% [markdown]
# To start we generate a fake image to work from, this image has fixed value regions and noisy regions to demonstrate the different features in ROI

# %%
NX = 256 
IMAGE = np.random.randn(NX, NX)

IMAGE[NX // 4 : NX // 2, NX // 4 : NX // 2] = 1
IMAGE[NX // 2 : 3*NX // 4, NX // 4 : NX // 2] = 2
IMAGE[NX // 4 : NX // 2, NX // 2 : 3*NX // 4] = 3
IMAGE[NX // 2 : 3*NX // 4, NX // 2 : 3*NX // 4] = 4

plt.imshow(IMAGE,cmap='bone')

# %% [markdown]
# To define a region-of-interest (ROI) we have several options:
